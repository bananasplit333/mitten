# %%
import os
import requests
from tools import quadratic_calculator, fib_list, convert_currency, query_library, search_web
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv
from langchain_core.prompts import ChatPromptTemplate


load_dotenv()
os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")

# %%
#initialize LLM 
llm = ChatOpenAI(
    model="gpt-5-nano"
)

# %%
#bind llm to tools
llm_with_tools = llm.bind_tools([quadratic_calculator, fib_list, convert_currency, query_library, search_web])

FUNCTION_NAMES = {
    "quadratic_calculator": quadratic_calculator,
    "fib_list": fib_list,
    "convert_currency": convert_currency,
    "query_library": query_library,
    "search_web": search_web
}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 #bind llm to tools
# ----> 2 llm_with_tools = llm.bind_tools([quadratic_calculator, fib_list, convert_currency, query_library, search_web])
#       4 FUNCTION_NAMES = {
#       5     "quadratic_calculator": quadratic_calculator,
#       6     "fib_list": fib_list,
#    (...)
#       9     "search_web": search_web
#      10 }
#
# NameError: name 'llm' is not defined

# %%
#generate the prompt 
prompt = ChatPromptTemplate([
    ("system", "You are a helpful agent that will be given a set of tools. Your only job is to execute the right one"),
    ("user", "{query}")
])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 #generate the prompt
# ----> 2 prompt = ChatPromptTemplate([
#       3     ("system", "You are a helpful agent that will be given a set of tools. Your only job is to execute the right one"),
#       4     ("user", "{query}")
#       5 ])
#
# NameError: name 'ChatPromptTemplate' is not defined

# %%
#query = "Search my library for information about what happens at the end of Dune"
query = "Search the web and recommend me the best skin care product for men"
#query = "can you help me find the solution for x**2 + 8x + 16?"
#query = "what are the first 20 numbers in the fibonacci sequence?"
#query = "how much is 10000000000 us dollars in us dollars?"

res = llm_with_tools.invoke(prompt.format_messages(query=query)).tool_calls

# %%
print(res)
# Out:
# [{'name': 'search_web', 'args': {'query': 'best skincare product for men 2025 reviews'}, 'id': 'call_8cHDmNotooHErx1TpS8kRaOW', 'type': 'tool_call'}]

# %%
#make sure tool was called
if not res:
    raise ValueError("No tool called")


#figure out which tool was called
fn = FUNCTION_NAMES[res[0]["name"]]

#call the tool 
ans = fn.invoke(res[0]["args"])

# %%
print(ans)
# Out:
# Here’s a concise synthesis of the provided sources on “best skincare product for men in 2025” and notable picks/themes you can use to guide a routine.
#
# Source summaries
#
# - Men’s Health — The 10 Best Skincare Brands for Men in 2025, Tested by an Expert
#   - Theme: Focus on brands that deliver clean ingredients, non-irritating formulas, good texture, long-term effectiveness. The author tested a wide range (moisturizers, serums, cleansers, etc.) across 50+ brands.
#   - Notable takeaway: Many top picks are fragrance-free or mildly scented to minimize irritation (e.g., Oil-Free Moisturizer, Daily Face Wash). Emphasizes products that are gentle and effective over time.
#
# - Dapper & Groomed — Best 5 Face Serums for Men in 2025 – Tested and Reviewed
#   - Theme: Targeted serums that deliver actives and visible results for men.
#   - Notable picks mentioned: Brickell Repairing Vitamin C Serum for Men; Kiehl's Age Defender Power Serum; ManLabs Titan Peptide Max Serum; The Ordinary (likely a vitamin C/peptide/peptide-related option among its lineup).
#   - Takeaway: A strong serum lineup can address aging, brightness, and skin texture; quality actives matter.
#
# - Wall Street Journal (WSJ) — The Best Skincare Products for Men, According to Dermatologists
#   - Theme: Dermatologist-endorsed, widely accessible picks.
#   - Notable examples cited: Cetaphil Gentle Skin Cleanser; Dove (brand examples show the mix of drugstore staples).
#   - Takeaway: Reputable, widely available cleansers are a solid foundation; dermatologist-backed options are a good starting point.
#
# - GQ — The Best Beauty Products for Men
#   - Theme: Broad guide spanning luxury to drugstore, aimed at building a complete man’s skincare routine.
#   - Takeaway: There are strong options across price points; it’s a good source for broad product ideas and category coverage (cleansers, serums, moisturizers, etc.).
#
# - Strive Skin — Men’s Skin Care Brands To Know
#   - Theme: Commentary on actives and transparency; critiques many brands for underdosing actives.
#   - Notable claim: Strive (the brand/brand-advocate) emphasizes transparent ingredient usage and meaningful active levels (e.g., 4–5% Niacinamide in certain formulations).
#   - Takeaway: If you want proven actives in meaningful concentrations, consider brands that report explicit actives and concentrations.
#
# Overall takeaways
# - A solid baseline routine for men in 2025 typically includes a gentle cleanser, a moisturizer (preferably fragrance-free or mildly scented), and daily sunscreen.
# - Serums with actives (vitamin C, peptides, niacinamide) are popular add-ons and can be chosen based on skin goals (brightening, anti-aging, hydration).
# - Fragrance-free or mild-scent formulas tend to be favored for reducing irritation, especially for sensitive skin.
# - For those who care about ingredient transparency and active levels, some brands highlighted (or argued for by industry pros) focus on clearly labeled actives and meaningful concentrations.
#
# Starter routine options (aligned with the sources)
#
# - Budget-friendly, straightforward routine
#   - Cleanser: Cetaphil Gentle Skin Cleanser or a Dove option (WSJ examples)
#   - Moisturizer: A fragrance-free moisturizer (e.g., a simple oil-free daily moisturizer as mentioned by Men’s Health)
#   - Sunscreen: A lightweight SPF daily option (not named in excerpts, but a staple in any routine)
#   - Optional serum: The Ordinary (basic serums with vitamin C/peptides) if you want actives without breaking the bank
#
# - Mid-range routine (more actives)
#   - Cleanser: Cetaphil or similar mild cleanser
#   - Serum: Kiehl’s Age Defender Power Serum or Brickell Vitamin C Serum for Men
#   - Moisturizer: A hydrating, non-irritating moisturizer (fragrance-free or mild-scent)
#   - Sunscreen: Daily sunscreen suitable for your skin type
#
# - Premium routine
#   - Cleanser: A dermatologist-approved option
#   - Serum: ManLabs Titan Peptide Max Serum or Brickell Vitamin C Serum, plus a peptide/niacinamide-focused option
#   - Moisturizer: A premium, fragrance-light daily moisturizer
#   - Sunscreen: High-quality daily SPF
#   - Optional: A Niacinamide-containing serum if you’re aiming for barrier support (as highlighted by Strive’s emphasis on active levels)
#
# Questions to tailor recommendations
# - What’s your skin type (oily, dry, combination, sensitive), and do you have any sensitivities or irritation concerns?
# - Do you prefer fragrance-free products or are mild fragrances okay?
# - What’s your budget range (drugstore, mid-range, premium)?
# - Are you primarily looking for anti-aging, brightening, hydration, or general maintenance?
# - Do you want a simple 3-step routine (cleanser, moisturizer, sunscreen) or a more full routine with serums?
#
# If you’d like, I can tailor a specific 3- or 4-step routine (with exact product recommendations and links) based on your skin type and budget, using the brands and products highlighted in these sources.
