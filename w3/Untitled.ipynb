# %%
import os
import requests 
from langchain_openai import OpenAI
from langchain_core.tools import tool
from dotenv import load_dotenv

load_dotenv()
os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")
api_key = os.getenv("API_FOOTBALL_API_KEY")

# %%
url = f"https://v1.basketball.api-sports.io"
payload={}
headers = {
    "x-apisports-key": api_key,
}

response = requests.request("GET", url+"/teams?id=139", headers=headers, data=payload)

print(response.text)
# Out:
# {"get":"teams","parameters":{"id":"139"},"errors":[],"results":1,"response":[{"id":139,"name":"Denver Nuggets","logo":"https:\/\/media.api-sports.io\/basketball\/teams\/139.png","nationnal":false,"country":{"id":5,"name":"USA","code":"US","flag":"https:\/\/media.api-sports.io\/flags\/us.svg"}}]}
